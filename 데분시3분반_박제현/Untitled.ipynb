# %%
sub_list = ['math', 'english', 'science', 'history']
score_list = [87, 94, 85, 92]
Fscore_list = [91, 98, 89, 96]
sem_dic = {"subject" : sub_list, 'M_scr' : score_list, 'F_scr' : Fscore_list }

# %%
import pandas as pd

df1 = pd.DataFrame(sem_dic)
df1
# Out:
#    subject  M_scr  F_scr
# 0     math     87     91
# 1  english     94     98
# 2  science     85     89
# 3  history     92     96

# %%
df2 = pd.DataFrame([score_list, Fscore_list], index = ['M_scr', 'F_scr'],columns = sub_list)
df2
# Out:
#        math  english  science  history
# M_scr    87       94       85       92
# F_scr    91       98       89       96

# %%
df1
# Out:
#    subject  M_scr  F_scr
# 0     math     87     91
# 1  english     94     98
# 2  science     85     89
# 3  history     92     96

# %%
df1.sort_index(ascending = False, inplace = True)  #df1=df1.sort_index()
df1
# Out:
#    subject  M_scr  F_scr
# 3  history     92     96
# 2  science     85     89
# 1  english     94     98
# 0     math     87     91

# %%
df1.sort_values('subject', ascending = False, inplace = True)
df1
# Out:
#    subject  M_scr  F_scr
# 2  science     85     89
# 0     math     87     91
# 3  history     92     96
# 1  english     94     98

# %%
df1.set_index('subject', inplace = True)
df1
# Out:
#          M_scr  F_scr
# subject
# science     85     89
# math        87     91
# history     92     96
# english     94     98

# %%
df1['M_scr']['math']
# Out:
# 87

# %%
df1['M_scr'][1] = 78
df1
# Out:
#          M_scr  F_scr
# subject
# science     85     89
# math        78     91
# history     92     96
# english     94     98

# %%
df1['sums'] = df1['M_scr'] + df1['F_scr']
df1
# Out:
#          M_scr  F_scr  sums
# subject
# science     85     89   174
# math        78     91   169
# history     92     96   188
# english     94     98   192

# %%
df1['average'] = df1['sums'] / 2
df1
# Out:
#          M_scr  F_scr  sums  average
# subject
# science     85     89   174     87.0
# math        78     91   169     84.5
# history     92     96   188     94.0
# english     94     98   192     96.0

# %%
df1['mean'] = df1['sums']/2

df1.assign( mean = df1['sums']/2)
df1
# Out:
#          M_scr  F_scr  sums  average  mean
# subject
# science     85     89   174     87.0  87.0
# math        78     91   169     84.5  84.5
# history     92     96   188     94.0  94.0
# english     94     98   192     96.0  96.0

# %%
import numpy as np

df1['grade'] = np.where(df1['mean']>=95, 'A+', np.where(df1['mean'] >= 90,  'Ao', 'B+'))
df1
# Out:
#          M_scr  F_scr  sums  average  mean grade
# subject
# science     85     89   174     87.0  87.0    B+
# math        78     91   169     84.5  84.5    B+
# history     92     96   188     94.0  94.0    Ao
# english     94     98   192     96.0  96.0    A+

# %%
df1.drop( columns = 'grade', inplace = True)
df1
# Out:
#          M_scr  F_scr  sums  average  mean
# subject
# science     85     89   174     87.0  87.0
# math        78     91   169     84.5  84.5
# history     92     96   188     94.0  94.0
# english     94     98   192     96.0  96.0

# %%
df1.drop( index = 'math', inplace = True)
df1
# Out:
#          M_scr  F_scr  sums  average  mean
# subject
# science     85     89   174     87.0  87.0
# history     92     96   188     94.0  94.0
# english     94     98   192     96.0  96.0

# %%
df1.drop(columns = 'average', inplace = True)
df1
# Out:
#          M_scr  F_scr  sums  mean
# subject
# science     85     89   174  87.0
# history     92     96   188  94.0
# english     94     98   192  96.0

# %%
df1.loc['average'] = df1.mean()
df1
# Out:
#              M_scr      F_scr        sums       mean
# subject
# science  85.000000  89.000000  174.000000  87.000000
# history  92.000000  96.000000  188.000000  94.000000
# english  94.000000  98.000000  192.000000  96.000000
# average  90.333333  94.333333  184.666667  92.333333

# %%
df1 = df1.round(2)
df1
# Out:
#          M_scr  F_scr    sums   mean
# subject
# science  85.00  89.00  174.00  87.00
# history  92.00  96.00  188.00  94.00
# english  94.00  98.00  192.00  96.00
# average  90.33  94.33  184.67  92.33

# %%
df1.loc['grade'] = np.where(df1.loc['average'] >= 92, 'A+', 'B+')
df1
# Out:
#          M_scr  F_scr    sums   mean
# subject
# science   85.0   89.0   174.0   87.0
# history   92.0   96.0   188.0   94.0
# english   94.0   98.0   192.0   96.0
# average  90.33  94.33  184.67  92.33
# grade       B+     A+      A+     A+

# %%
df1.reset_index(inplace = True)
df1
# Out:
#    subject  M_scr  F_scr    sums   mean
# 0  science   85.0   89.0   174.0   87.0
# 1  history   92.0   96.0   188.0   94.0
# 2  english   94.0   98.0   192.0   96.0
# 3  average  90.33  94.33  184.67  92.33
# 4    grade     B+     A+      A+     A+

# %%
df1.drop(columns = ['sums', 'mean'], index = 4, inplace = True)
df1
# Out:
#    subject  M_scr  F_scr
# 0  science   85.0   89.0
# 1  history   92.0   96.0
# 2  english   94.0   98.0
# 3  average  90.33  94.33

# %%
df2.sort_values(columns = 'F_scr', ascending = False, inplace = True)
df1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [24], in <cell line: 1>()
# ----> 1 df2.sort_values(columns = 'F_scr', ascending = False, inplace = True)
#       2 df1
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# TypeError: sort_values() got an unexpected keyword argument 'columns'
